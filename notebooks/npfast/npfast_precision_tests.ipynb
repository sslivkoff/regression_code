# %% [markdown]
# # test the precision of npfast functions

# %% [markdown]
# ### tests
# - npfast functions are applied to random matrices of different numerical ranges
# - ranges
#     - **medium** [0, 1]
#     - **small** [0, 1] / 10000
#     - **tiny** [0, 1] / 10000000
#     - **big** [0, 1] * 10000
#     - **huge** [0, 1] * 10000000
# - the first function in each function set is taken as ground truth
#     - see test_npfast.test_precision() for function execution details
# - absolute and relative error are displayed for each
#     - see test_utils.test_equal() for precision evaluation details
# - not tested
#     - correlations between significantly different magnitudes of data
#     - nonuniform distributions of data
#     - different lengths of axes
#     - real datasets
# - tests performed on dmt15 (mkl, 8 core)
#
#
# ### results
# - correlation functions are the least precise
#     - probably still acceptable with absolute accuracy of 1e-6 in most cases
# - different numerical ranges have different accuracies
#     - small and big values (~1e4 or ~1e-4) are least precise
#     - tiny and huge values (~1e7 or ~1e-7) are most precise
#         - possibly because floating point number system is sparse at scale changes
# - need further testing on different matrix sizes
#
# ### todo
# - see **More Thourough Analysis** section at bottom for future analysis if required

# %%
from __future__ import print_function

import collections

import numpy as np

from regression_code.storm import npfast
from regression_code.storm.tests import test_utils
from regression_code.storm.npfast.tests import test_npfast

# %% [markdown]
# # float32 values between 0 and 1

# %%
X = np.random.rand(10000, 10000).astype(np.float32)
Y = np.random.rand(*X.shape).astype(X.dtype)

test_npfast.test_precision(X, Y, add_nans=10)
# Out:
# Testing precision of sum functions
# - np.sum : all_close=False
#     - abs within +- 1e-08: 10000 / 10000
#     - rel within */ 1e-08: 10000 / 10000
# - thread_sum : all_close=False
#     - abs within +- 1e-08: 10000 / 10000
#     - rel within */ 1e-08: 10000 / 10000
# - dot_sum : all_close=False
#     - abs within +- 1e-08: 10000 / 10000
#     - rel within */ 1e-08: 10000 / 10000
#
# Testing precision of mean functions
# - np.mean : all_close=False
#     - abs within +- 1e-08: 10000 / 10000
#     - rel within */ 1e-08: 10000 / 10000
# - dot_mean : all_close=False
#     - abs within +- 1e-08: 10000 / 10000
#     - rel within */ 1e-08: 10000 / 10000
#
# Testing precision of std functions
# - np.std : all_close=False
#     - abs within +- 1e-08: 10000 / 10000
#     - rel within */ 1e-08: 10000 / 10000
# - arithmetic_std : all_close=False
#     - abs within +- 1e-08: 10000 / 10000
#     - rel within */ 1e-08: 10000 / 10000
# - dot_std : all_close=False
#     - abs within +- 1e-08: 80 / 10000
#     - abs within +- 1e-07: 532 / 10000
#     - abs within +- 1e-06: 4643 / 10000
#     - abs within +- 1e-05: 10000 / 10000
#     - rel within */ 1e-08: 80 / 10000
#     - rel within */ 1e-07: 80 / 10000
#     - rel within */ 1e-06: 1428 / 10000
#     - rel within */ 1e-05: 9281 / 10000
#     - rel within */ 1e-04: 10000 / 10000
# - dot_std_inplace : all_close=False
#     - abs within +- 1e-08: 80 / 10000
#     - abs within +- 1e-07: 532 / 10000
#     - abs within +- 1e-06: 4643 / 10000
#     - abs within +- 1e-05: 10000 / 10000
#     - rel within */ 1e-08: 80 / 10000
#     - rel within */ 1e-07: 80 / 10000
#     - rel within */ 1e-06: 1428 / 10000
#     - rel within */ 1e-05: 9281 / 10000
#     - rel within */ 1e-04: 10000 / 10000
# - numexpr_std : all_close=False
#     - abs within +- 1e-08: 8226 / 10000
#     - abs within +- 1e-07: 10000 / 10000
#     - rel within */ 1e-08: 8226 / 10000
#     - rel within */ 1e-07: 8226 / 10000
#     - rel within */ 1e-06: 10000 / 10000
# - dot_std_demeaned : all_close=False
#     - abs within +- 1e-08: 8226 / 10000
#     - abs within +- 1e-07: 10000 / 10000
#     - rel within */ 1e-08: 8226 / 10000
#     - rel within */ 1e-07: 8226 / 10000
#     - rel within */ 1e-06: 10000 / 10000
# - dot_std_inplace_demeaned : all_close=False
#     - abs within +- 1e-08: 8226 / 10000
#     - abs within +- 1e-07: 10000 / 10000
#     - rel within */ 1e-08: 8226 / 10000
#     - rel within */ 1e-07: 8226 / 10000
#     - rel within */ 1e-06: 10000 / 10000
# - numexpr_std_demeaned : all_close=False
#     - abs within +- 1e-08: 8226 / 10000
#     - abs within +- 1e-07: 10000 / 10000
#     - rel within */ 1e-08: 8226 / 10000
#     - rel within */ 1e-07: 8226 / 10000
#     - rel within */ 1e-06: 10000 / 10000
#
# Testing precision of zscore functions
# - scipy.zscore : all_close=False
#     - abs within +-
# /auto/k1/storm/python_path/repos/regression_code/storm/tests/test_utils.py:109: RuntimeWarning: invalid value encountered in less
#   n_same = (abs_difference < tol).sum()
# /auto/k1/storm/python_path/repos/regression_code/storm/tests/test_utils.py:134: RuntimeWarning: invalid value encountered in greater
#   n_same = N - (rel_difference > tol).sum()
# /auto/k1/storm/python_path/repos/regression_code/storm/tests/test_utils.py:125: RuntimeWarning: invalid value encountered in divide
#   result1 / result2 - 1,
#  1e-08: 100000000 / 100000000
#     - rel within */ 1e-08: 100000000 / 100000000
# - np_arithmetic : all_close=False
#     - abs within +- 1e-08: 100000000 / 100000000
#     - rel within */ 1e-08: 100000000 / 100000000
# - dot : all_close=False
#     - abs within +- 1e-08: 1219108 / 100000000
#     - abs within +- 1e-07: 4623671 / 100000000
#     - abs within +- 1e-06: 27656589 / 100000000
#     - abs within +- 1e-05: 91441476 / 100000000
#     - abs within +- 1e-04: 100000000 / 100000000
#     - rel within */ 1e-08: 820263 / 100000000
#     - rel within */ 1e-07: 820263 / 100000000
#     - rel within */ 1e-06: 14320008 / 100000000
#     - rel within */ 1e-05: 92816443 / 100000000
#     - rel within */ 1e-04: 100000000 / 100000000
# - dot_inplace : all_close=False
#     - abs within +- 1e-08: 83539943 / 100000000
#     - abs within +- 1e-07: 91023786 / 100000000
#     - abs within +- 1e-06: 100000000 / 100000000
#     - rel within */ 1e-08: 82471872 / 100000000
#     - rel within */ 1e-07: 82471872 / 100000000
#     - rel within */ 1e-06: 100000000 / 100000000
# - arithmetic_demeaned : all_close=False
#     - abs within +- 1e-08: 32331249 / 100000000
#     - abs within +- 1e-07: 54162395 / 100000000
#     - abs within +- 1e-06: 99806389 / 100000000
#     - abs within +- 1e-05: 100000000 / 100000000
#     - rel within */ 1e-08: 29501233 / 100000000
#     - rel within */ 1e-07: 29501233 / 100000000
#     - rel within */ 1e-06: 99968254 / 100000000
#     - rel within */ 1e-05: 100000000 / 100000000
# - dot_demeaned : all_close=False
#     - abs within +- 1e-08: 83539943 / 100000000
#     - abs within +- 1e-07: 91023786 / 100000000
#     - abs within +- 1e-06: 100000000 / 100000000
#     - rel within */ 1e-08: 82471872 / 100000000
#     - rel within */ 1e-07: 82471872 / 100000000
#     - rel within */ 1e-06: 100000000 / 100000000
# - dot_inplace_demeaned : all_close=False
#     - abs within +- 1e-08: 83539943 / 100000000
#     - abs within +- 1e-07: 91023786 / 100000000
#     - abs within +- 1e-06: 100000000 / 100000000
#     - rel within */ 1e-08: 82471872 / 100000000
#     - rel within */ 1e-07: 82471872 / 100000000
#     - rel within */ 1e-06: 100000000 / 100000000
# - numexpr : all_close=False
#     - abs within +- 1e-08: 83539943 / 100000000
#     - abs within +- 1e-07: 91023786 / 100000000
#     - abs within +- 1e-06: 100000000 / 100000000
#     - rel within */ 1e-08: 82471872 / 100000000
#     - rel within */ 1e-07: 82471872 / 100000000
#     - rel within */ 1e-06: 100000000 / 100000000
# - numexpr_demeaned : all_close=False
#     - abs within +- 1e-08: 30520194 / 100000000
#     - abs within +- 1e-07: 53240672 / 100000000
#     - abs within +- 1e-06: 99804080 / 100000000
#     - abs within +- 1e-05: 100000000 / 100000000
#     - rel within */ 1e-08: 27559465 / 100000000
#     - rel within */ 1e-07: 27559465 / 100000000
#     - rel within */ 1e-06: 99968786 / 100000000
#     - rel within */ 1e-05: 100000000 / 100000000
# - numexpr_inplace : all_close=False
#     - abs within +- 1e-08: 83539943 / 100000000
#     - abs within +- 1e-07: 91023786 / 100000000
#     - abs within +- 1e-06: 100000000 / 100000000
#     - rel within */ 1e-08: 82471872 / 100000000
#     - rel within */ 1e-07: 82471872 / 100000000
#     - rel within */ 1e-06: 100000000 / 100000000
# - numexpr_inplace_demeaned : all_close=False
#     - abs within +- 1e-08: 30520194 / 100000000
#     - abs within +- 1e-07: 53240672 / 100000000
#     - abs within +- 1e-06: 99804080 / 100000000
#     - abs within +- 1e-05: 100000000 / 100000000
#     - rel within */ 1e-08: 27559465 / 100000000
#     - rel within */ 1e-07: 27559465 / 100000000
#     - rel within */ 1e-06: 99968786 / 100000000
#     - rel within */ 1e-05: 100000000 / 100000000
#
# Testing precision of correlation functions
# - scipy_zscore : all_close=False
#     - abs within +- 1e-08: 10000 / 10000
#     - rel within */ 1e-08: 10000 / 10000
# - arithmetic : all_close=False
#     - abs within +- 1e-08: 10000 / 10000
#     - rel within */ 1e-08: 10000 / 10000
# - dot : all_close=False
#     - abs within +- 1e-08: 2326 / 10000
#     - abs within +- 1e-07: 8408 / 10000
#     - abs within +- 1e-06: 10000 / 10000
#     - rel within */ 1e-08: 81 / 10000
#     - rel within */ 1e-07: 81 / 10000
#     - rel within */ 1e-06: 1110 / 10000
#     - rel within */ 1e-05: 7217 / 10000
#     - rel within */ 1e-04: 9923 / 10000
#     - rel within */ 1e-03: 9993 / 10000
#     - rel within */ 1e-02: 10000 / 10000
# - dot_inplace : all_close=False
#     - abs within +- 1e-08: 9661 / 10000
#     - abs within +- 1e-07: 10000 / 10000
#     - rel within */ 1e-08: 6887 / 10000
#     - rel within */ 1e-07: 6887 / 10000
#     - rel within */ 1e-06: 8897 / 10000
#     - rel within */ 1e-05: 9916 / 10000
#     - rel within */ 1e-04: 9990 / 10000
#     - rel within */ 1e-03: 9999 / 10000
#     - rel within */ 1e-02: 10000 / 10000
# - numexpr : all_close=False
#     - abs within +- 1e-08: 9492 / 10000
#     - abs within +- 1e-07: 10000 / 10000
#     - rel within */ 1e-08: 840 / 10000
#     - rel within */ 1e-07: 840 / 10000
#     - rel within */ 1e-06: 7316 / 10000
#     - rel within */ 1e-05: 9764 / 10000
#     - rel within */ 1e-04: 9975 / 10000
#     - rel within */ 1e-03: 9999 / 10000
#     - rel within */ 1e-02: 10000 / 10000
# - arithmetic_1_zscored : all_close=False
#     - abs within +- 1e-08: 10000 / 10000
#     - rel within */ 1e-08: 10000 / 10000
# - inplace_1_zscored : all_close=False
#     - abs within +- 1e-08: 9816 / 10000
#     - abs within +- 1e-07: 10000 / 10000
#     - rel within */ 1e-08: 8238 / 10000
#     - rel within */ 1e-07: 8238 / 10000
#     - rel within */ 1e-06: 9383 / 10000
#     - rel within */ 1e-05: 9954 / 10000
#     - rel within */ 1e-04: 9994 / 10000
#     - rel within */ 1e-03: 10000 / 10000
# - arithmetic_2_zscored : all_close=False
#     - abs within +- 1e-08: 10000 / 10000
#     - rel within */ 1e-08: 10000 / 10000
# - inplace_2_zscored : all_close=False
#     - abs within +- 1e-08: 10000 / 10000
#     - rel within */ 1e-08: 10000 / 10000
# - numexpr_1_zscored : all_close=False
#     - abs within +- 1e-08: 9816 / 10000
#     - abs within +- 1e-07: 10000 / 10000
#     - rel within */ 1e-08: 8238 / 10000
#     - rel within */ 1e-07: 8238 / 10000
#     - rel within */ 1e-06: 9383 / 10000
#     - rel within */ 1e-05: 9954 / 10000
#     - rel within */ 1e-04: 9994 / 10000
#     - rel within */ 1e-03: 10000 / 10000
# - numexpr_2_zscored : all_close=False
#     - abs within +- 1e-08: 10000 / 10000
#     - rel within */ 1e-08: 10000 / 10000
#
# Testing precision of isnan functions
# - np.isnan : all_close=True
# - numexpr_isnan : all_close=True
#
# Testing precision of nan_to_num functions
# - np.nan_to_num : all_close=True
# - numexpr : all_close=True
# - numexpr_inplace : all_close=True
#
# Testing precision of copy functions
# - np.copy : all_close=False
#     - abs within +- 1e-08: 100000000 / 100000000
#     - rel within */ 1e-08: 100000000 / 100000000
# - numexpr_copy : all_close=False
#     - abs within +- 1e-08: 100000000 / 100000000
#     - rel within */ 1e-08: 100000000 / 100000000
# /auto/k1/storm/python_path/repos/regression_code/storm/tests/test_utils.py:126: RuntimeWarning: invalid value encountered in divide
#   result2 / result1 - 1,

# %% [markdown]
# # small float32 values

# %%
X = np.random.rand(10000, 10000).astype(np.float32) / 10000
Y = np.random.rand(*X.shape).astype(X.dtype) / 10000

test_npfast.test_precision(X, Y, add_nans=10)
# Out:
# Testing precision of sum functions
# - np.sum : all_close=False
#     - abs within +- 1e-08: 10000 / 10000
#     - rel within */ 1e-08: 10000 / 10000
# - thread_sum : all_close=False
#     - abs within +- 1e-08: 10000 / 10000
#     - rel within */ 1e-08: 10000 / 10000
# - dot_sum : all_close=False
#     - abs within +- 1e-08: 10000 / 10000
#     - rel within */ 1e-08: 10000 / 10000
#
# Testing precision of mean functions
# - np.mean : all_close=False
#     - abs within +- 1e-08: 10000 / 10000
#     - rel within */ 1e-08: 10000 / 10000
# - dot_mean : all_close=False
#     - abs within +- 1e-08: 10000 / 10000
#     - rel within */ 1e-08: 10000 / 10000
#
# Testing precision of std functions
# - np.std : all_close=False
#     - abs within +- 1e-08: 10000 / 10000
#     - rel within */ 1e-08: 10000 / 10000
# - arithmetic_std : all_close=False
#     - abs within +- 1e-08: 10000 / 10000
#     - rel within */ 1e-08: 10000 / 10000
# - dot_std : all_close=False
#     - abs within +- 1e-08: 10000 / 10000
#     - rel within */ 1e-08: 74 / 10000
#     - rel within */ 1e-07: 74 / 10000
#     - rel within */ 1e-06: 1540 / 10000
#     - rel within */ 1e-05: 9522 / 10000
#     - rel within */ 1e-04: 10000 / 10000
# - dot_std_inplace : all_close=False
#     - abs within +- 1e-08: 10000 / 10000
#     - rel within */ 1e-08: 74 / 10000
#     - rel within */ 1e-07: 74 / 10000
#     - rel within */ 1e-06: 1540 / 10000
#     - rel within */ 1e-05: 9522 / 10000
#     - rel within */ 1e-04: 10000 / 10000
# - numexpr_std : all_close=False
#     - abs within +- 1e-08: 10000 / 10000
#     - rel within */ 1e-08: 6560 / 10000
#     - rel within */ 1e-07: 6560 / 10000
#     - rel within */ 1e-06: 10000 / 10000
# - dot_std_demeaned : all_close=False
#     - abs within +- 1e-08: 10000 / 10000
#     - rel within */ 1e-08: 6560 / 10000
#     - rel within */ 1e-07: 6560 / 10000
#     - rel within */ 1e-06: 10000 / 10000
# - dot_std_inplace_demeaned : all_close=False
#     - abs within +- 1e-08: 10000 / 10000
#     - rel within */ 1e-08: 6560 / 10000
#     - rel within */ 1e-07: 6560 / 10000
#     - rel within */ 1e-06: 10000 / 10000
# - numexpr_std_demeaned : all_close=False
#     - abs within +- 1e-08: 10000 / 10000
#     - rel within */ 1e-08: 6560 / 10000
#     - rel within */ 1e-07: 6560 / 10000
#     - rel within */ 1e-06: 10000 / 10000
#
# Testing precision of zscore functions
# - scipy.zscore : all_close=False
#     - abs within +- 1e-08: 100000000 / 100000000
#     - rel within */ 1e-08: 100000000 / 100000000
# - np_arithmetic : all_close=False
#     - abs within +- 1e-08: 100000000 / 100000000
#     - rel within */ 1e-08: 100000000 / 100000000
# - dot : all_close=False
#     - abs within +- 1e-08: 1388572 / 100000000
#     - abs within +- 1e-07: 5007666 / 100000000
#     - abs within +- 1e-06: 29663369 / 100000000
#     - abs within +- 1e-05: 93627761 / 100000000
#     - abs within +- 1e-04: 100000000 / 100000000
#     - rel within */ 1e-08: 967550 / 100000000
#     - rel within */ 1e-07: 967550 / 100000000
#     - rel within */ 1e-06: 15521711 / 100000000
#     - rel within */ 1e-05: 95222442 / 100000000
#     - rel within */ 1e-04: 100000000 / 100000000
# - dot_inplace : all_close=False
#     - abs within +- 1e-08: 75768842 / 100000000
#     - abs within +- 1e-07: 89469954 / 100000000
#     - abs within +- 1e-06: 100000000 / 100000000
#     - rel within */ 1e-08: 73811575 / 100000000
#     - rel within */ 1e-07: 73811575 / 100000000
#     - rel within */ 1e-06: 100000000 / 100000000
# - arithmetic_demeaned : all_close=False
#     - abs within +- 1e-08: 31263058 / 100000000
#     - abs within +- 1e-07: 55609537 / 100000000
#     - abs within +- 1e-06: 99881013 / 100000000
#     - abs within +- 1e-05: 100000000 / 100000000
#     - rel within */ 1e-08: 28026431 / 100000000
#     - rel within */ 1e-07: 28026431 / 100000000
#     - rel within */ 1e-06: 99989973 / 100000000
#     - rel within */ 1e-05: 100000000 / 100000000
# - dot_demeaned : all_close=False
#     - abs within +- 1e-08: 75768842 / 100000000
#     - abs within +- 1e-07: 89469954 / 100000000
#     - abs within +- 1e-06: 100000000 / 100000000
#     - rel within */ 1e-08: 73811575 / 100000000
#     - rel within */ 1e-07: 73811575 / 100000000
#     - rel within */ 1e-06: 100000000 / 100000000
# - dot_inplace_demeaned : all_close=False
#     - abs within +- 1e-08: 75768842 / 100000000
#     - abs within +- 1e-07: 89469954 / 100000000
#     - abs within +- 1e-06: 100000000 / 100000000
#     - rel within */ 1e-08: 73811575 / 100000000
#     - rel within */ 1e-07: 73811575 / 100000000
#     - rel within */ 1e-06: 100000000 / 100000000
# - numexpr : all_close=False
#     - abs within +- 1e-08: 75768842 / 100000000
#     - abs within +- 1e-07: 89469954 / 100000000
#     - abs within +- 1e-06: 100000000 / 100000000
#     - rel within */ 1e-08: 73811575 / 100000000
#     - rel within */ 1e-07: 73811575 / 100000000
#     - rel within */ 1e-06: 100000000 / 100000000
# - numexpr_demeaned : all_close=False
#     - abs within +- 1e-08: 28434047 / 100000000
#     - abs within +- 1e-07: 54102489 / 100000000
#     - abs within +- 1e-06: 99877333 / 100000000
#     - abs within +- 1e-05: 100000000 / 100000000
#     - rel within */ 1e-08: 25015290 / 100000000
#     - rel within */ 1e-07: 25015290 / 100000000
#     - rel within */ 1e-06: 99989987 / 100000000
#     - rel within */ 1e-05: 100000000 / 100000000
# - numexpr_inplace : all_close=False
#     - abs within +- 1e-08: 75768842 / 100000000
#     - abs within +- 1e-07: 89469954 / 100000000
#     - abs within +- 1e-06: 100000000 / 100000000
#     - rel within */ 1e-08: 73811575 / 100000000
#     - rel within */ 1e-07: 73811575 / 100000000
#     - rel within */ 1e-06: 100000000 / 100000000
# - numexpr_inplace_demeaned : all_close=False
#     - abs within +- 1e-08: 28434047 / 100000000
#     - abs within +- 1e-07: 54102489 / 100000000
#     - abs within +- 1e-06: 99877333 / 100000000
#     - abs within +- 1e-05: 100000000 / 100000000
#     - rel within */ 1e-08: 25015290 / 100000000
#     - rel within */ 1e-07: 25015290 / 100000000
#     - rel within */ 1e-06: 99989987 / 100000000
#     - rel within */ 1e-05: 100000000 / 100000000
#
# Testing precision of correlation functions
# - scipy_zscore : all_close=False
#     - abs within +- 1e-08: 10000 / 10000
#     - rel within */ 1e-08: 10000 / 10000
# - arithmetic : all_close=False
#     - abs within +- 1e-08: 10000 / 10000
#     - rel within */ 1e-08: 10000 / 10000
# - dot : all_close=False
#     - abs within +- 1e-08: 2404 / 10000
#     - abs within +- 1e-07: 8678 / 10000
#     - abs within +- 1e-06: 10000 / 10000
#     - rel within */ 1e-08: 92 / 10000
#     - rel within */ 1e-07: 92 / 10000
#     - rel within */ 1e-06: 1171 / 10000
#     - rel within */ 1e-05: 7450 / 10000
#     - rel within */ 1e-04: 9931 / 10000
#     - rel within */ 1e-03: 9996 / 10000
#     - rel within */ 1e-02: 10000 / 10000
# - dot_inplace : all_close=False
#     - abs within +- 1e-08: 9671 / 10000
#     - abs within +- 1e-07: 10000 / 10000
#     - rel within */ 1e-08: 4744 / 10000
#     - rel within */ 1e-07: 4744 / 10000
#     - rel within */ 1e-06: 8432 / 10000
#     - rel within */ 1e-05: 9852 / 10000
#     - rel within */ 1e-04: 9995 / 10000
#     - rel within */ 1e-03: 10000 / 10000
# - numexpr : all_close=False
#     - abs within +- 1e-08: 9518 / 10000
#     - abs within +- 1e-07: 10000 / 10000
#     - rel within */ 1e-08: 816 / 10000
#     - rel within */ 1e-07: 816 / 10000
#     - rel within */ 1e-06: 7456 / 10000
#     - rel within */ 1e-05: 9779 / 10000
#     - rel within */ 1e-04: 9981 / 10000
#     - rel within */ 1e-03: 9999 / 10000
#     - rel within */ 1e-02: 10000 / 10000
# - arithmetic_1_zscored : all_close=False
#     - abs within +- 1e-08: 10000 / 10000
#     - rel within */ 1e-08: 10000 / 10000
# - inplace_1_zscored : all_close=False
#     - abs within +- 1e-08: 9819 / 10000
#     - abs within +- 1e-07: 10000 / 10000
#     - rel within */ 1e-08: 6824 / 10000
#     - rel within */ 1e-07: 6824 / 10000
#     - rel within */ 1e-06: 9061 / 10000
#     - rel within */ 1e-05: 9909 / 10000
#     - rel within */ 1e-04: 9997 / 10000
#     - rel within */ 1e-03: 10000 / 10000
# - arithmetic_2_zscored : all_close=False
#     - abs within +- 1e-08: 10000 / 10000
#     - rel within */ 1e-08: 10000 / 10000
# - inplace_2_zscored : all_close=False
#     - abs within +- 1e-08: 10000 / 10000
#     - rel within */ 1e-08: 10000 / 10000
# - numexpr_1_zscored : all_close=False
#     - abs within +- 1e-08: 9819 / 10000
#     - abs within +- 1e-07: 10000 / 10000
#     - rel within */ 1e-08: 6824 / 10000
#     - rel within */ 1e-07: 6824 / 10000
#     - rel within */ 1e-06: 9061 / 10000
#     - rel within */ 1e-05: 9909 / 10000
#     - rel within */ 1e-04: 9997 / 10000
#     - rel within */ 1e-03: 10000 / 10000
# - numexpr_2_zscored : all_close=False
#     - abs within +- 1e-08: 10000 / 10000
#     - rel within */ 1e-08: 10000 / 10000
#
# Testing precision of isnan functions
# - np.isnan : all_close=True
# - numexpr_isnan : all_close=True
#
# Testing precision of nan_to_num functions
# - np.nan_to_num : all_close=True
# - numexpr : all_close=True
# - numexpr_inplace : all_close=True
#
# Testing precision of copy functions
# - np.copy : all_close=False
#     - abs within +- 1e-08: 100000000 / 100000000
#     - rel within */ 1e-08: 100000000 / 100000000
# - numexpr_copy : all_close=False
#     - abs within +- 1e-08: 100000000 / 100000000
#     - rel within */ 1e-08: 100000000 / 100000000

# %% [markdown]
# # tiny float32 values

# %%
X = np.random.rand(10000, 10000).astype(np.float32) / 10000000
Y = np.random.rand(*X.shape).astype(X.dtype) / 10000000

test_npfast.test_precision(X, Y, add_nans=10)
# Out:
# Testing precision of sum functions
# - np.sum : all_close=False
#     - abs within +- 1e-08: 10000 / 10000
#     - rel within */ 1e-08: 10000 / 10000
# - thread_sum : all_close=False
#     - abs within +- 1e-08: 10000 / 10000
#     - rel within */ 1e-08: 10000 / 10000
# - dot_sum : all_close=False
#     - abs within +- 1e-08: 10000 / 10000
#     - rel within */ 1e-08: 10000 / 10000
#
# Testing precision of mean functions
# - np.mean : all_close=False
#     - abs within +- 1e-08: 10000 / 10000
#     - rel within */ 1e-08: 10000 / 10000
# - dot_mean : all_close=False
#     - abs within +- 1e-08: 10000 / 10000
#     - rel within */ 1e-08: 10000 / 10000
#
# Testing precision of std functions
# - np.std : all_close=False
#     - abs within +- 1e-08: 10000 / 10000
#     - rel within */ 1e-08: 10000 / 10000
# - arithmetic_std : all_close=False
#     - abs within +- 1e-08: 10000 / 10000
#     - rel within */ 1e-08: 10000 / 10000
# - dot_std : all_close=False
#     - abs within +- 1e-08: 10000 / 10000
#     - rel within */ 1e-08: 10000 / 10000
# - dot_std_inplace : all_close=False
#     - abs within +- 1e-08: 10000 / 10000
#     - rel within */ 1e-08: 10000 / 10000
# - numexpr_std : all_close=False
#     - abs within +- 1e-08: 10000 / 10000
#     - rel within */ 1e-08: 10000 / 10000
# - dot_std_demeaned : all_close=False
#     - abs within +- 1e-08: 10000 / 10000
#     - rel within */ 1e-08: 10000 / 10000
# - dot_std_inplace_demeaned : all_close=False
#     - abs within +- 1e-08: 10000 / 10000
#     - rel within */ 1e-08: 10000 / 10000
# - numexpr_std_demeaned : all_close=False
#     - abs within +- 1e-08: 10000 / 10000
#     - rel within */ 1e-08: 10000 / 10000
#
# Testing precision of zscore functions
# - scipy.zscore : all_close=False
#     - abs within +- 1e-08: 100000000 / 100000000
#     - rel within */ 1e-08: 100000000 / 100000000
# - np_arithmetic : all_close=False
#     - abs within +- 1e-08: 100000000 / 100000000
#     - rel within */ 1e-08: 100000000 / 100000000
# - dot : all_close=False
#     - abs within +- 1e-08: 100000000 / 100000000
#     - rel within */ 1e-08: 100000000 / 100000000
# - dot_inplace : all_close=False
#     - abs within +- 1e-08: 100000000 / 100000000
#     - rel within */ 1e-08: 100000000 / 100000000
# - arithmetic_demeaned : all_close=False
#     - abs within +- 1e-08: 100000000 / 100000000
#     - rel within */ 1e-08: 100000000 / 100000000
# - dot_demeaned : all_close=False
#     - abs within +- 1e-08: 100000000 / 100000000
#     - rel within */ 1e-08: 100000000 / 100000000
# - dot_inplace_demeaned : all_close=False
#     - abs within +- 1e-08: 100000000 / 100000000
#     - rel within */ 1e-08: 100000000 / 100000000
# - numexpr : all_close=False
#     - abs within +- 1e-08: 100000000 / 100000000
#     - rel within */ 1e-08: 100000000 / 100000000
# - numexpr_demeaned : all_close=False
#     - abs within +- 1e-08: 100000000 / 100000000
#     - rel within */ 1e-08: 100000000 / 100000000
# - numexpr_inplace : all_close=False
#     - abs within +- 1e-08: 100000000 / 100000000
#     - rel within */ 1e-08: 100000000 / 100000000
# - numexpr_inplace_demeaned : all_close=False
#     - abs within +- 1e-08: 100000000 / 100000000
#     - rel within */ 1e-08: 100000000 / 100000000
#
# Testing precision of correlation functions
# - scipy_zscore : all_close=False
#     - abs within +- 1e-08: 10000 / 10000
#     - rel within */ 1e-08: 10000 / 10000
# - arithmetic : all_close=False
#     - abs within +- 1e-08: 10000 / 10000
#     - rel within */ 1e-08: 10000 / 10000
# - dot : all_close=False
#     - abs within +- 1e-08: 10000 / 10000
#     - rel within */ 1e-08: 10000 / 10000
# - dot_inplace : all_close=False
#     - abs within +- 1e-08: 10000 / 10000
#     - rel within */ 1e-08: 10000 / 10000
# - numexpr : all_close=False
#     - abs within +- 1e-08: 10000 / 10000
#     - rel within */ 1e-08: 10000 / 10000
# - arithmetic_1_zscored : all_close=False
#     - abs within +- 1e-08: 10000 / 10000
#     - rel within */ 1e-08: 10000 / 10000
# - inplace_1_zscored : all_close=False
#     - abs within +- 1e-08: 10000 / 10000
#     - rel within */ 1e-08: 10000 / 10000
# - arithmetic_2_zscored : all_close=False
#     - abs within +- 1e-08: 10000 / 10000
#     - rel within */ 1e-08: 10000 / 10000
# - inplace_2_zscored : all_close=False
#     - abs within +- 1e-08: 10000 / 10000
#     - rel within */ 1e-08: 10000 / 10000
# - numexpr_1_zscored : all_close=False
#     - abs within +- 1e-08: 10000 / 10000
#     - rel within */ 1e-08: 10000 / 10000
# - numexpr_2_zscored : all_close=False
#     - abs within +- 1e-08: 10000 / 10000
#     - rel within */ 1e-08: 10000 / 10000
#
# Testing precision of isnan functions
# - np.isnan : all_close=True
# - numexpr_isnan : all_close=True
#
# Testing precision of nan_to_num functions
# - np.nan_to_num : all_close=True
# - numexpr : all_close=True
# - numexpr_inplace : all_close=True
#
# Testing precision of copy functions
# - np.copy : all_close=False
#     - abs within +- 1e-08: 100000000 / 100000000
#     - rel within */ 1e-08: 100000000 / 100000000
# - numexpr_copy : all_close=False
#     - abs within +- 1e-08: 100000000 / 100000000
#     - rel within */ 1e-08: 100000000 / 100000000

# %% [markdown]
# # big float32 values

# %%
X = np.random.rand(10000, 10000).astype(np.float32) * 10000
Y = np.random.rand(*X.shape).astype(X.dtype) * 10000

test_npfast.test_precision(X, Y, add_nans=10)
# Out:
# Testing precision of sum functions
# - np.sum : all_close=False
#     - abs within +- 1e-08: 10000 / 10000
#     - rel within */ 1e-08: 10000 / 10000
# - thread_sum : all_close=False
#     - abs within +- 1e-08: 10000 / 10000
#     - rel within */ 1e-08: 10000 / 10000
# - dot_sum : all_close=False
#     - abs within +- 1e-08: 10000 / 10000
#     - rel within */ 1e-08: 10000 / 10000
#
# Testing precision of mean functions
# - np.mean : all_close=False
#     - abs within +- 1e-08: 10000 / 10000
#     - rel within */ 1e-08: 10000 / 10000
# - dot_mean : all_close=False
#     - abs within +- 1e-08: 10000 / 10000
#     - rel within */ 1e-08: 10000 / 10000
#
# Testing precision of std functions
# - np.std : all_close=False
#     - abs within +- 1e-08: 10000 / 10000
#     - rel within */ 1e-08: 10000 / 10000
# - arithmetic_std : all_close=False
#     - abs within +- 1e-08: 10000 / 10000
#     - rel within */ 1e-08: 10000 / 10000
# - dot_std : all_close=False
#     - abs within +- 1e-08: 60 / 10000
#     - abs within +- 1e-07: 60 / 10000
#     - abs within +- 1e-06: 60 / 10000
#     - abs within +- 1e-05: 60 / 10000
#     - abs within +- 1e-04: 60 / 10000
#     - abs within +- 1e-03: 530 / 10000
#     - abs within +- 1e-02: 4635 / 10000
#     - abs within +- 1e-01: 10000 / 10000
#     - rel within */ 1e-08: 60 / 10000
#     - rel within */ 1e-07: 60 / 10000
#     - rel within */ 1e-06: 1397 / 10000
#     - rel within */ 1e-05: 9253 / 10000
#     - rel within */ 1e-04: 10000 / 10000
# - dot_std_inplace : all_close=False
#     - abs within +- 1e-08: 60 / 10000
#     - abs within +- 1e-07: 60 / 10000
#     - abs within +- 1e-06: 60 / 10000
#     - abs within +- 1e-05: 60 / 10000
#     - abs within +- 1e-04: 60 / 10000
#     - abs within +- 1e-03: 530 / 10000
#     - abs within +- 1e-02: 4635 / 10000
#     - abs within +- 1e-01: 10000 / 10000
#     - rel within */ 1e-08: 60 / 10000
#     - rel within */ 1e-07: 60 / 10000
#     - rel within */ 1e-06: 1397 / 10000
#     - rel within */ 1e-05: 9253 / 10000
#     - rel within */ 1e-04: 10000 / 10000
# - numexpr_std : all_close=False
#     - abs within +- 1e-08: 6680 / 10000
#     - abs within +- 1e-07: 6680 / 10000
#     - abs within +- 1e-06: 6680 / 10000
#     - abs within +- 1e-05: 6680 / 10000
#     - abs within +- 1e-04: 6680 / 10000
#     - abs within +- 1e-03: 10000 / 10000
#     - rel within */ 1e-08: 6680 / 10000
#     - rel within */ 1e-07: 6680 / 10000
#     - rel within */ 1e-06: 10000 / 10000
# - dot_std_demeaned : all_close=False
#     - abs within +- 1e-08: 6680 / 10000
#     - abs within +- 1e-07: 6680 / 10000
#     - abs within +- 1e-06: 6680 / 10000
#     - abs within +- 1e-05: 6680 / 10000
#     - abs within +- 1e-04: 6680 / 10000
#     - abs within +- 1e-03: 10000 / 10000
#     - rel within */ 1e-08: 6680 / 10000
#     - rel within */ 1e-07: 6680 / 10000
#     - rel within */ 1e-06: 10000 / 10000
# - dot_std_inplace_demeaned : all_close=False
#     - abs within +- 1e-08: 6680 / 10000
#     - abs within +- 1e-07: 6680 / 10000
#     - abs within +- 1e-06: 6680 / 10000
#     - abs within +- 1e-05: 6680 / 10000
#     - abs within +- 1e-04: 6680 / 10000
#     - abs within +- 1e-03: 10000 / 10000
#     - rel within */ 1e-08: 6680 / 10000
#     - rel within */ 1e-07: 6680 / 10000
#     - rel within */ 1e-06: 10000 / 10000
# - numexpr_std_demeaned : all_close=False
#     - abs within +- 1e-08: 6680 / 10000
#     - abs within +- 1e-07: 6680 / 10000
#     - abs within +- 1e-06: 6680 / 10000
#     - abs within +- 1e-05: 6680 / 10000
#     - abs within +- 1e-04: 6680 / 10000
#     - abs within +- 1e-03: 10000 / 10000
#     - rel within */ 1e-08: 6680 / 10000
#     - rel within */ 1e-07: 6680 / 10000
#     - rel within */ 1e-06: 10000 / 10000
#
# Testing precision of zscore functions
# - scipy.zscore : all_close=False
#     - abs within +- 1e-08: 100000000 / 100000000
#     - rel within */ 1e-08: 100000000 / 100000000
# - np_arithmetic : all_close=False
#     - abs within +- 1e-08: 100000000 / 100000000
#     - rel within */ 1e-08: 100000000 / 100000000
# - dot : all_close=False
#     - abs within +- 1e-08: 1069830 / 100000000
#     - abs within +- 1e-07: 4427644 / 100000000
#     - abs within +- 1e-06: 27647648 / 100000000
#     - abs within +- 1e-05: 91375114 / 100000000
#     - abs within +- 1e-04: 100000000 / 100000000
#     - rel within */ 1e-08: 678353 / 100000000
#     - rel within */ 1e-07: 678353 / 100000000
#     - rel within */ 1e-06: 14103029 / 100000000
#     - rel within */ 1e-05: 92520846 / 100000000
#     - rel within */ 1e-04: 100000000 / 100000000
# - dot_inplace : all_close=False
#     - abs within +- 1e-08: 71188312 / 100000000
#     - abs within +- 1e-07: 85922661 / 100000000
#     - abs within +- 1e-06: 100000000 / 100000000
#     - rel within */ 1e-08: 69082577 / 100000000
#     - rel within */ 1e-07: 69082577 / 100000000
#     - rel within */ 1e-06: 100000000 / 100000000
# - arithmetic_demeaned : all_close=False
#     - abs within +- 1e-08: 30484561 / 100000000
#     - abs within +- 1e-07: 53914106 / 100000000
#     - abs within +- 1e-06: 99829000 / 100000000
#     - abs within +- 1e-05: 100000000 / 100000000
#     - rel within */ 1e-08: 27401903 / 100000000
#     - rel within */ 1e-07: 27401903 / 100000000
#     - rel within */ 1e-06: 99949410 / 100000000
#     - rel within */ 1e-05: 100000000 / 100000000
# - dot_demeaned : all_close=False
#     - abs within +- 1e-08: 71188312 / 100000000
#     - abs within +- 1e-07: 85922661 / 100000000
#     - abs within +- 1e-06: 100000000 / 100000000
#     - rel within */ 1e-08: 69082577 / 100000000
#     - rel within */ 1e-07: 69082577 / 100000000
#     - rel within */ 1e-06: 100000000 / 100000000
# - dot_inplace_demeaned : all_close=False
#     - abs within +- 1e-08: 71188312 / 100000000
#     - abs within +- 1e-07: 85922661 / 100000000
#     - abs within +- 1e-06: 100000000 / 100000000
#     - rel within */ 1e-08: 69082577 / 100000000
#     - rel within */ 1e-07: 69082577 / 100000000
#     - rel within */ 1e-06: 100000000 / 100000000
# - numexpr : all_close=False
#     - abs within +- 1e-08: 71188312 / 100000000
#     - abs within +- 1e-07: 85922661 / 100000000
#     - abs within +- 1e-06: 100000000 / 100000000
#     - rel within */ 1e-08: 69082577 / 100000000
#     - rel within */ 1e-07: 69082577 / 100000000
#     - rel within */ 1e-06: 100000000 / 100000000
# - numexpr_demeaned : all_close=False
#     - abs within +- 1e-08: 27749251 / 100000000
#     - abs within +- 1e-07: 52325244 / 100000000
#     - abs within +- 1e-06: 99822258 / 100000000
#     - abs within +- 1e-05: 100000000 / 100000000
#     - rel within */ 1e-08: 24504406 / 100000000
#     - rel within */ 1e-07: 24504406 / 100000000
#     - rel within */ 1e-06: 99949410 / 100000000
#     - rel within */ 1e-05: 100000000 / 100000000
# - numexpr_inplace : all_close=False
#     - abs within +- 1e-08: 71188312 / 100000000
#     - abs within +- 1e-07: 85922661 / 100000000
#     - abs within +- 1e-06: 100000000 / 100000000
#     - rel within */ 1e-08: 69082577 / 100000000
#     - rel within */ 1e-07: 69082577 / 100000000
#     - rel within */ 1e-06: 100000000 / 100000000
# - numexpr_inplace_demeaned : all_close=False
#     - abs within +- 1e-08: 27749251 / 100000000
#     - abs within +- 1e-07: 52325244 / 100000000
#     - abs within +- 1e-06: 99822258 / 100000000
#     - abs within +- 1e-05: 100000000 / 100000000
#     - rel within */ 1e-08: 24504406 / 100000000
#     - rel within */ 1e-07: 24504406 / 100000000
#     - rel within */ 1e-06: 99949410 / 100000000
#     - rel within */ 1e-05: 100000000 / 100000000
#
# Testing precision of correlation functions
# - scipy_zscore : all_close=False
#     - abs within +- 1e-08: 10000 / 10000
#     - rel within */ 1e-08: 10000 / 10000
# - arithmetic : all_close=False
#     - abs within +- 1e-08: 10000 / 10000
#     - rel within */ 1e-08: 10000 / 10000
# - dot : all_close=False
#     - abs within +- 1e-08: 2300 / 10000
#     - abs within +- 1e-07: 8396 / 10000
#     - abs within +- 1e-06: 10000 / 10000
#     - rel within */ 1e-08: 79 / 10000
#     - rel within */ 1e-07: 79 / 10000
#     - rel within */ 1e-06: 1114 / 10000
#     - rel within */ 1e-05: 7138 / 10000
#     - rel within */ 1e-04: 9921 / 10000
#     - rel within */ 1e-03: 9993 / 10000
#     - rel within */ 1e-02: 9999 / 10000
#     - rel within */ 1e-01: 10000 / 10000
# - dot_inplace : all_close=False
#     - abs within +- 1e-08: 9552 / 10000
#     - abs within +- 1e-07: 10000 / 10000
#     - rel within */ 1e-08: 4880 / 10000
#     - rel within */ 1e-07: 4880 / 10000
#     - rel within */ 1e-06: 8361 / 10000
#     - rel within */ 1e-05: 9851 / 10000
#     - rel within */ 1e-04: 9984 / 10000
#     - rel within */ 1e-03: 9997 / 10000
#     - rel within */ 1e-02: 10000 / 10000
# - numexpr : all_close=False
#     - abs within +- 1e-08: 9391 / 10000
#     - abs within +- 1e-07: 10000 / 10000
#     - rel within */ 1e-08: 816 / 10000
#     - rel within */ 1e-07: 816 / 10000
#     - rel within */ 1e-06: 7330 / 10000
#     - rel within */ 1e-05: 9755 / 10000
#     - rel within */ 1e-04: 9976 / 10000
#     - rel within */ 1e-03: 9997 / 10000
#     - rel within */ 1e-02: 10000 / 10000
# - arithmetic_1_zscored : all_close=False
#     - abs within +- 1e-08: 10000 / 10000
#     - rel within */ 1e-08: 10000 / 10000
# - inplace_1_zscored : all_close=False
#     - abs within +- 1e-08: 9745 / 10000
#     - abs within +- 1e-07: 10000 / 10000
#     - rel within */ 1e-08: 6984 / 10000
#     - rel within */ 1e-07: 6984 / 10000
#     - rel within */ 1e-06: 9043 / 10000
#     - rel within */ 1e-05: 9929 / 10000
#     - rel within */ 1e-04: 9996 / 10000
#     - rel within */ 1e-03: 10000 / 10000
# - arithmetic_2_zscored : all_close=False
#     - abs within +- 1e-08: 10000 / 10000
#     - rel within */ 1e-08: 10000 / 10000
# - inplace_2_zscored : all_close=False
#     - abs within +- 1e-08: 10000 / 10000
#     - rel within */ 1e-08: 10000 / 10000
# - numexpr_1_zscored : all_close=False
#     - abs within +- 1e-08: 9745 / 10000
#     - abs within +- 1e-07: 10000 / 10000
#     - rel within */ 1e-08: 6984 / 10000
#     - rel within */ 1e-07: 6984 / 10000
#     - rel within */ 1e-06: 9043 / 10000
#     - rel within */ 1e-05: 9929 / 10000
#     - rel within */ 1e-04: 9996 / 10000
#     - rel within */ 1e-03: 10000 / 10000
# - numexpr_2_zscored : all_close=False
#     - abs within +- 1e-08: 10000 / 10000
#     - rel within */ 1e-08: 10000 / 10000
#
# Testing precision of isnan functions
# - np.isnan : all_close=True
# - numexpr_isnan : all_close=True
#
# Testing precision of nan_to_num functions
# - np.nan_to_num : all_close=True
# - numexpr : all_close=True
# - numexpr_inplace : all_close=True
#
# Testing precision of copy functions
# - np.copy : all_close=False
#     - abs within +- 1e-08: 100000000 / 100000000
#     - rel within */ 1e-08: 100000000 / 100000000
# - numexpr_copy : all_close=False
#     - abs within +- 1e-08: 100000000 / 100000000
#     - rel within */ 1e-08: 100000000 / 100000000

# %% [markdown]
# # huge float32 values

# %%
X = np.random.rand(10000, 10000).astype(np.float32) * 10000000
Y = np.random.rand(*X.shape).astype(X.dtype) * 10000000

test_npfast.test_precision(X, Y, add_nans=10)
# Out:
# Testing precision of sum functions
# - np.sum : all_close=False
#     - abs within +- 1e-08: 10000 / 10000
#     - rel within */ 1e-08: 10000 / 10000
# - thread_sum : all_close=False
#     - abs within +- 1e-08: 10000 / 10000
#     - rel within */ 1e-08: 10000 / 10000
# - dot_sum : all_close=False
#     - abs within +- 1e-08: 10000 / 10000
#     - rel within */ 1e-08: 10000 / 10000
#
# Testing precision of mean functions
# - np.mean : all_close=False
#     - abs within +- 1e-08: 10000 / 10000
#     - rel within */ 1e-08: 10000 / 10000
# - dot_mean : all_close=False
#     - abs within +- 1e-08: 10000 / 10000
#     - rel within */ 1e-08: 10000 / 10000
#
# Testing precision of std functions
# - np.std : all_close=False
#     - abs within +- 1e-08: 10000 / 10000
#     - rel within */ 1e-08: 10000 / 10000
# - arithmetic_std : all_close=False
#     - abs within +- 1e-08: 10000 / 10000
#     - rel within */ 1e-08: 10000 / 10000
# - dot_std : all_close=False
#     - abs within +- 1e-08: 3180 / 10000
#     - abs within +- 1e-07: 10000 / 10000
#     - rel within */ 1e-08: 10000 / 10000
# - dot_std_inplace : all_close=False
#     - abs within +- 1e-08: 3180 / 10000
#     - abs within +- 1e-07: 10000 / 10000
#     - rel within */ 1e-08: 10000 / 10000
# - numexpr_std : all_close=False
#     - abs within +- 1e-08: 10000 / 10000
#     - rel within */ 1e-08: 10000 / 10000
# - dot_std_demeaned : all_close=False
#     - abs within +- 1e-08: 10000 / 10000
#     - rel within */ 1e-08: 10000 / 10000
# - dot_std_inplace_demeaned : all_close=False
#     - abs within +- 1e-08: 10000 / 10000
#     - rel within */ 1e-08: 10000 / 10000
# - numexpr_std_demeaned : all_close=False
#     - abs within +- 1e-08: 10000 / 10000
#     - rel within */ 1e-08: 10000 / 10000
#
# Testing precision of zscore functions
# - scipy.zscore : all_close=False
#     - abs within +- 1e-08: 100000000 / 100000000
#     - rel within */ 1e-08: 100000000 / 100000000
# - np_arithmetic : all_close=False
#     - abs within +- 1e-08: 100000000 / 100000000
#     - rel within */ 1e-08: 100000000 / 100000000
# - dot : all_close=False
#     - abs within +- 1e-08: 100000000 / 100000000
#     - rel within */ 1e-08: 100000000 / 100000000
# - dot_inplace : all_close=False
#     - abs within +- 1e-08: 100000000 / 100000000
#     - rel within */ 1e-08: 100000000 / 100000000
# - arithmetic_demeaned : all_close=False
#     - abs within +- 1e-08: 100000000 / 100000000
#     - rel within */ 1e-08: 100000000 / 100000000
# - dot_demeaned : all_close=False
#     - abs within +- 1e-08: 100000000 / 100000000
#     - rel within */ 1e-08: 100000000 / 100000000
# - dot_inplace_demeaned : all_close=False
#     - abs within +- 1e-08: 100000000 / 100000000
#     - rel within */ 1e-08: 100000000 / 100000000
# - numexpr : all_close=False
#     - abs within +- 1e-08: 100000000 / 100000000
#     - rel within */ 1e-08: 100000000 / 100000000
# - numexpr_demeaned : all_close=False
#     - abs within +- 1e-08: 100000000 / 100000000
#     - rel within */ 1e-08: 100000000 / 100000000
# - numexpr_inplace : all_close=False
#     - abs within +- 1e-08: 100000000 / 100000000
#     - rel within */ 1e-08: 100000000 / 100000000
# - numexpr_inplace_demeaned : all_close=False
#     - abs within +- 1e-08: 100000000 / 100000000
#     - rel within */ 1e-08: 100000000 / 100000000
#
# Testing precision of correlation functions
# - scipy_zscore : all_close=False
#     - abs within +- 1e-08: 10000 / 10000
#     - rel within */ 1e-08: 10000 / 10000
# - arithmetic : all_close=False
#     - abs within +- 1e-08: 10000 / 10000
#     - rel within */ 1e-08: 10000 / 10000
# - dot : all_close=False
#     - abs within +- 1e-08: 10000 / 10000
#     - rel within */ 1e-08: 10000 / 10000
# - dot_inplace : all_close=False
#     - abs within +- 1e-08: 10000 / 10000
#     - rel within */ 1e-08: 10000 / 10000
# - numexpr : all_close=False
#     - abs within +- 1e-08: 10000 / 10000
#     - rel within */ 1e-08: 10000 / 10000
# - arithmetic_1_zscored : all_close=False
#     - abs within +- 1e-08: 10000 / 10000
#     - rel within */ 1e-08: 10000 / 10000
# - inplace_1_zscored : all_close=False
#     - abs within +- 1e-08: 10000 / 10000
#     - rel within */ 1e-08: 10000 / 10000
# - arithmetic_2_zscored : all_close=False
#     - abs within +- 1e-08: 10000 / 10000
#     - rel within */ 1e-08: 10000 / 10000
# - inplace_2_zscored : all_close=False
#     - abs within +- 1e-08: 10000 / 10000
#     - rel within */ 1e-08: 10000 / 10000
# - numexpr_1_zscored : all_close=False
#     - abs within +- 1e-08: 10000 / 10000
#     - rel within */ 1e-08: 10000 / 10000
# - numexpr_2_zscored : all_close=False
#     - abs within +- 1e-08: 10000 / 10000
#     - rel within */ 1e-08: 10000 / 10000
#
# Testing precision of isnan functions
# - np.isnan : all_close=True
# - numexpr_isnan : all_close=True
#
# Testing precision of nan_to_num functions
# - np.nan_to_num : all_close=True
# - numexpr : all_close=True
# - numexpr_inplace : all_close=True
#
# Testing precision of copy functions
# - np.copy : all_close=False
#     - abs within +- 1e-08: 100000000 / 100000000
#     - rel within */ 1e-08: 100000000 / 100000000
# - numexpr_copy : all_close=False
#     - abs within +- 1e-08: 100000000 / 100000000
#     - rel within */ 1e-08: 100000000 / 100000000

# %% [markdown]
# # float64 tests

# %%
X = np.random.rand(10000, 10000).astype(np.float64) * 10000
Y = np.random.rand(*X.shape).astype(X.dtype) * 10000

# %%
test_npfast.test_precision(X, Y, add_nans=10)
# Out:
# Testing precision of sum functions
# - np.sum : all_close=False
#     - abs within +- 1e-08: 10000 / 10000
#     - rel within */ 1e-08: 10000 / 10000
# - thread_sum : all_close=False
#     - abs within +- 1e-08: 10000 / 10000
#     - rel within */ 1e-08: 10000 / 10000
# - dot_sum : all_close=False
#     - abs within +- 1e-08: 10000 / 10000
#     - rel within */ 1e-08: 10000 / 10000
#
# Testing precision of mean functions
# - np.mean : all_close=False
#     - abs within +- 1e-08: 10000 / 10000
#     - rel within */ 1e-08: 10000 / 10000
# - dot_mean : all_close=False
#     - abs within +- 1e-08: 10000 / 10000
#     - rel within */ 1e-08: 10000 / 10000
#
# Testing precision of std functions
# - np.std : all_close=False
#     - abs within +- 1e-08: 10000 / 10000
#     - rel within */ 1e-08: 10000 / 10000
# - arithmetic_std : all_close=False
#     - abs within +- 1e-08: 10000 / 10000
#     - rel within */ 1e-08: 10000 / 10000
# - dot_std : all_close=False
#     - abs within +- 1e-08: 10000 / 10000
#     - rel within */ 1e-08: 10000 / 10000
# - dot_std_inplace : all_close=False
#     - abs within +- 1e-08: 10000 / 10000
#     - rel within */ 1e-08: 10000 / 10000
# - numexpr_std : all_close=False
#     - abs within +- 1e-08: 10000 / 10000
#     - rel within */ 1e-08: 10000 / 10000
# - dot_std_demeaned : all_close=False
#     - abs within +- 1e-08: 10000 / 10000
#     - rel within */ 1e-08: 10000 / 10000
# - dot_std_inplace_demeaned : all_close=False
#     - abs within +- 1e-08: 10000 / 10000
#     - rel within */ 1e-08: 10000 / 10000
# - numexpr_std_demeaned : all_close=False
#     - abs within +- 1e-08: 10000 / 10000
#     - rel within */ 1e-08: 10000 / 10000
#
# Testing precision of zscore functions
# - scipy.zscore : all_close=False
#     - abs within +- 1e-08: 100000000 / 100000000
#     - rel within */ 1e-08: 100000000 / 100000000
# - np_arithmetic : all_close=False
#     - abs within +- 1e-08: 100000000 / 100000000
#     - rel within */ 1e-08: 100000000 / 100000000
# - dot : all_close=False
#     - abs within +- 1e-08: 100000000 / 100000000
#     - rel within */ 1e-08: 100000000 / 100000000
# - dot_inplace : all_close=False
#     - abs within +- 1e-08: 100000000 / 100000000
#     - rel within */ 1e-08: 100000000 / 100000000
# - arithmetic_demeaned : all_close=False
#     - abs within +- 1e-08: 100000000 / 100000000
#     - rel within */ 1e-08: 100000000 / 100000000
# - dot_demeaned : all_close=False
#     - abs within +- 1e-08: 100000000 / 100000000
#     - rel within */ 1e-08: 100000000 / 100000000
# - dot_inplace_demeaned : all_close=False
#     - abs within +- 1e-08: 100000000 / 100000000
#     - rel within */ 1e-08: 100000000 / 100000000
# - numexpr : all_close=False
#     - abs within +- 1e-08: 100000000 / 100000000
#     - rel within */ 1e-08: 100000000 / 100000000
# - numexpr_demeaned : all_close=False
#     - abs within +- 1e-08: 100000000 / 100000000
#     - rel within */ 1e-08: 100000000 / 100000000
# - numexpr_inplace : all_close=False
#     - abs within +- 1e-08: 100000000 / 100000000
#     - rel within */ 1e-08: 100000000 / 100000000
# - numexpr_inplace_demeaned : all_close=False
#     - abs within +- 1e-08: 100000000 / 100000000
#     - rel within */ 1e-08: 100000000 / 100000000
#
# Testing precision of correlation functions
# - scipy_zscore : all_close=False
#     - abs within +- 1e-08: 10000 / 10000
#     - rel within */ 1e-08: 10000 / 10000
# - arithmetic : all_close=False
#     - abs within +- 1e-08: 10000 / 10000
#     - rel within */ 1e-08: 10000 / 10000
# - dot : all_close=False
#     - abs within +- 1e-08: 10000 / 10000
#     - rel within */ 1e-08: 10000 / 10000
# - dot_inplace : all_close=False
#     - abs within +- 1e-08: 10000 / 10000
#     - rel within */ 1e-08: 10000 / 10000
# - numexpr : all_close=False
#     - abs within +- 1e-08: 10000 / 10000
#     - rel within */ 1e-08: 10000 / 10000
# - arithmetic_1_zscored : all_close=False
#     - abs within +- 1e-08: 10000 / 10000
#     - rel within */ 1e-08: 10000 / 10000
# - inplace_1_zscored : all_close=False
#     - abs within +- 1e-08: 10000 / 10000
#     - rel within */ 1e-08: 10000 / 10000
# - arithmetic_2_zscored : all_close=False
#     - abs within +- 1e-08: 10000 / 10000
#     - rel within */ 1e-08: 10000 / 10000
# - inplace_2_zscored : all_close=False
#     - abs within +- 1e-08: 10000 / 10000
#     - rel within */ 1e-08: 10000 / 10000
# - numexpr_1_zscored : all_close=False
#     - abs within +- 1e-08: 10000 / 10000
#     - rel within */ 1e-08: 10000 / 10000
# - numexpr_2_zscored : all_close=False
#     - abs within +- 1e-08: 10000 / 10000
#     - rel within */ 1e-08: 10000 / 10000
#
# Testing precision of isnan functions
# - np.isnan : all_close=True
# - numexpr_isnan : all_close=True
#
# Testing precision of nan_to_num functions
# - np.nan_to_num : all_close=True
# - numexpr : all_close=True
# - numexpr_inplace : all_close=True
#
# Testing precision of copy functions
# - np.copy : all_close=False
#     - abs within +- 1e-08: 100000000 / 100000000
#     - rel within */ 1e-08: 100000000 / 100000000
# - numexpr_copy : all_close=False
#     - abs within +- 1e-08: 100000000 / 100000000
#     - rel within */ 1e-08: 100000000 / 100000000

# %% [markdown]
# # More Thorough Analysis [incomplete]
# - measure precision under all possible combinations of parameters
# - also use real datasets to test precission

# %%
raise NotImplementedError()
# Out:
# ---------------------------------------------------------------------------
# NotImplementedError                       Traceback (most recent call last)
# <ipython-input-9-b34b57902732> in <module>()
# ----> 1 raise NotImplementedError()
#
# NotImplementedError:

# %%
dtypes = collections.OrderedDict([
    ['float32', np.float32],
    ['float64', np.float64],
])

multipliers = collections.OrderedDict([
    ['medium', 1],
    ['small', 1 / 10000],
    ['tiny', 1 / 10000000],
    ['big', 10000],
    ['huge', 10000000],
])

sizes = collections.OrderedDict([
    ['small', 100],
    ['medium', 1000],
    ['big', 10000],
    ['huge', 100000],
])

distributions = collections.OrderedDict([
    ['uniform', lambda shape: np.random.rand(*shape)],
    ['normal', lambda shape: np.random.randn(*shape)],
    ['poisson', lambda shape: np.random.poison(10, shape)],
])

n_repeats = 10
axis_1_size = 10000

# %%
def trial_type(dtype, multiplier, size, distribution):
    metadata = [
        ['dtype', dtype],
        ['multiplier', multiplier],
        ['size', size],
        ['distribution', distribution],
    ]
    return ','.join(field + '=' + value for field, value in metadata)

# %% [markdown]
# # intialize results datastructure

# %%
results = {}

for dtype_name, dtype in dtypes.items():
    for multiplier_name, multiplier in multipliers.items():
        for size_name, size in sizes.items():
            for distribution_name, distribution in distributions.items():
                trial_name = trial_type(dtype_name, multiplier_name, size_name, distribution_name)
                results.setdefault(trial_name, {})
                for function_set_name, function_set in test_npfast.all_functions.items():
                    results[trial_name].setdefault(function_set_name, {})
                    for function_name, tolerances in function_set.items():
                        results[trial_name][function_set_name].setdefault(function_name, {})
                        for tolerance_name in test_utils.tols:
                            results[trial_name][function_set_name][function_name].setdefault(tolerance_name, float(0))

# %% [markdown]
# # compute results for each trial type

# %%
for repeat in range(n_repeats):
    for dtype_name, dtype in dtypes.items():
        for multiplier_name, multiplier in multipliers.items():
            for size_name, size in sizes.items():
                for distribution_name, distribution in distributions.items():
                    X = distribution((size, axis_1_size)).astype(dtype)
                    X *= multiplier
                    Y = distribution((size, axis_1_size)).astype(dtype)
                    Y *= multiplier

                    trial_results = test_precision(X, Y)
                    trial_name = trial_name(dtype_name, multiplier_name, size_name, distribution_name)
                    for function_set_name, function_set in trial_results.items():
                        for function_name, tolerances in function_set.items():
                            for tolerance_name, count in tolerances.items():
                                results[trial_name][function_set_name][function_name][tolerance_name] += count

# %% [markdown]
# # display results for each trial type

# %%
# for repeat in range(n_repeats):
for dtype_name, dtype in dtypes.items():
    for multiplier_name, multiplier in multipliers.items():
        for size_name, size in sizes.items():
            for distribution_name, distribution in distributions.items():
                test_name = trial_type(dtype_name, multiplier_name, size_name, distribution_name)
                print(test_name)
                print(len(test_name) * '=')
                print()
